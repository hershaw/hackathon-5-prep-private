# %%
import pandas as pd

from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split

# %%
twenty_train = fetch_20newsgroups(subset='train', shuffle=True, random_state=42, remove=('headers', 'footers', 'quotes'))
twenty_test = fetch_20newsgroups(subset='test', shuffle=True, random_state=42, remove=('headers', 'footers', 'quotes'))

# %%
# Clean texts
test_data = [sententence.str.replace('[^A-Za-z\s]+', '') for sentence in twenty_test.data]
train_data = [sententence.str.replace('[^A-Za-z\s]+', '') for sentence in twenty_test.data]

# Create dataframes
train_df = pd.DataFrame()
train_df['message'] = twenty_train.data
train_df['newsgroup'] = twenty_train.target

test_df  = pd.DataFrame() 
test_df['message'] = twenty_test.data
test_df['newsgroup'] = twenty_test.target

# Replace labels with real name
dictionary = {k: v for k, v in enumerate(twenty_test.target_names)}
train_df.replace({"newsgroup": dictionary}, inplace=True)
test_df.replace({"newsgroup": dictionary}, inplace=True)

test_df_labels  = test_df[['newsgroup']]
test_df_messages = test_df[['message']]

# Save dataframes as csv
train_df.to_csv('../data/train.csv', index=False, encoding='utf8', line_terminator='\n')
test_df_messages.to_csv('../data/test.csv', index=False, encoding='utf8', line_terminator='\n')
test_df_labels.to_csv('../data/labels.csv', index=False, encoding='utf8', line_terminator='\n')

print(len(train_df), len(test_df_messages), len(test_df_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-03e86cec4a68> in <module>()
#       1 # Clean texts
# ----> 2 test_data = [sententence.str.replace('[^A-Za-z\s]+', '') for sentence in twenty_test.data]
#       3
#       4 # Create dataframes
#       5 train_df = pd.DataFrame()
#
# <ipython-input-7-03e86cec4a68> in <listcomp>(.0)
#       1 # Clean texts
# ----> 2 test_data = [sententence.str.replace('[^A-Za-z\s]+', '') for sentence in twenty_test.data]
#       3
#       4 # Create dataframes
#       5 train_df = pd.DataFrame()
#
# NameError: name 'sententence' is not defined

# %%
t_df = pd.read_csv("train.csv", encoding = "ISO-8859-1")
len(t_df)
# Out:
# 11314

# %%
t_df.head(5)
# Out:
#                                              message                newsgroup
# 0  \r\n\r\nAnd/or taking the rubber ball out of t...  comp.os.ms-windows.misc
# 1  \r\nI'll pick up that PM and have a look -- ma...                rec.autos
# 2  FOR SALE(of course)\r\n\r\nLinear Power model ...             misc.forsale
# 3  [ ..see previous article on this debate for th...            comp.graphics
# 4  \r\n\r\nBefore they do some real damage??  You...                sci.crypt

# %%
print(t_df['message'][70])
# Out:
# : Pardon me? Here is to an amherst-clown:
# :
# : "Your three chiefs, Dro, Hamazasp and Kulkhandanian are the ringleaders
# :  of the bands which have destroyed Tartar villages and have staged
# :  massacres in Zangezour, Surmali, Etchmiadzin, and Zangibasar. This is
# :  intolerable.
#
#
# Were you expecting a different response? Here is another one:
#
# Source: K. S. Papazian, "Patriotism Perverted," Baikar Press, Boston, 1934,
#         (73 pages with Appendix).
#
# p. 25 (third paragraph)
#
# "Some real fighters sprang up from among the people, who struck terror
#  into the hearts of the Turks."
#
#
# "Within a few months after the war began, these Armenian guerrilla
#  forces, operating in close coordination with the Russians, were
#  savagely attacking Turkish cities, towns and villages in the east,
#  massacring their inhabitants without mercy, while at the same time
#  working to sabotage the Ottoman army's war effort by destroying roads
# ...

# %%
twenty_test.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']
